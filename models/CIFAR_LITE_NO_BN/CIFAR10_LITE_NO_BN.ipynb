# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1,
)
datagen.fit(x_train)

# Model architecture
def build_model():
    model = models.Sequential()

    # Block 1
    model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)))
    model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D())

    # Block 2
    model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D())

    # Block 3 (reduced)
    model.add(layers.Conv2D(96, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D())

    # Dense
    model.add(layers.Flatten())
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))

    return model


model = build_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks
lr_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=5, factor=0.5, verbose=1)
early_stop = EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True)

# Train
history = model.fit(datagen.flow(x_train, y_train, batch_size=64),
                    validation_data=(x_test, y_test),
                    epochs=100,
                    callbacks=[lr_reduction, early_stop],
                    verbose=1)

# Evaluate
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc * 100:.2f}%")

# Plotting
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Test')
plt.title('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Test')
plt.title('Loss')
plt.legend()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 43ms/step - accuracy: 0.3226 - loss: 1.8361 - val_accuracy: 0.5684 - val_loss: 1.2288 - learning_rate: 0.0010
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.5761 - loss: 1.1870 - val_accuracy: 0.6582 - val_loss: 0.9538 - learning_rate: 0.0010
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.6510 - loss: 0.9881 - val_accuracy: 0.6899 - val_loss: 0.9025 - learning_rate: 0.0010
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6882 - loss: 0.8777 - val_accuracy: 0.7360 - val_loss: 0.7699 - learning_rate: 0.0010
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.7242 - loss: 0.7895 - val_accuracy: 0.7184 - val_loss: 0.8013 - learning_rate: 0.0010
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.7358 - loss: 0.7553 - val_accuracy: 0.7596 - val_loss: 0.7050 - learning_rate: 0.0010
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.7562 - loss: 0.6997 - val_accuracy: 0.7642 - val_loss: 0.7120 - learning_rate: 0.0010
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.7630 - loss: 0.6783 - val_accuracy: 0.7819 - val_loss: 0.6334 - learning_rate: 0.0010
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.7760 - loss: 0.6495 - val_accuracy: 0.7660 - val_loss: 0.7109 - learning_rate: 0.0010
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.7861 - loss: 0.6174 - val_accuracy: 0.7746 - val_loss: 0.6718 - learning_rate: 0.0010
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 36ms/step - accuracy: 0.7918 - loss: 0.5924 - val_accuracy: 0.7844 - val_loss: 0.6451 - learning_rate: 0.0010
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.7941 - loss: 0.5846 - val_accuracy: 0.7929 - val_loss: 0.6147 - learning_rate: 0.0010
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.8033 - loss: 0.5661 - val_accuracy: 0.7975 - val_loss: 0.6061 - learning_rate: 0.0010
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8074 - loss: 0.5541 - val_accuracy: 0.8009 - val_loss: 0.6159 - learning_rate: 0.0010
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8128 - loss: 0.5350 - val_accuracy: 0.7954 - val_loss: 0.6050 - learning_rate: 0.0010
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.8222 - loss: 0.5159 - val_accuracy: 0.8114 - val_loss: 0.5859 - learning_rate: 0.0010
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8235 - loss: 0.5042 - val_accuracy: 0.8147 - val_loss: 0.5683 - learning_rate: 0.0010
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8291 - loss: 0.4950 - val_accuracy: 0.8207 - val_loss: 0.5556 - learning_rate: 0.0010
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.8330 - loss: 0.4832 - val_accuracy: 0.8003 - val_loss: 0.6029 - learning_rate: 0.0010
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8308 - loss: 0.4820 - val_accuracy: 0.8222 - val_loss: 0.5586 - learning_rate: 0.0010
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8332 - loss: 0.4804 - val_accuracy: 0.8075 - val_loss: 0.5935 - learning_rate: 0.0010
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.8396 - loss: 0.4617 - val_accuracy: 0.8006 - val_loss: 0.6346 - learning_rate: 0.0010
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8416 - loss: 0.4504 - val_accuracy: 0.8069 - val_loss: 0.5881 - learning_rate: 0.0010
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.8430 - loss: 0.4517 - val_accuracy: 0.8145 - val_loss: 0.5922 - learning_rate: 0.0010
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8418 - loss: 0.4502
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.8418 - loss: 0.4502 - val_accuracy: 0.8114 - val_loss: 0.5781 - learning_rate: 0.0010
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8636 - loss: 0.3902 - val_accuracy: 0.8310 - val_loss: 0.5486 - learning_rate: 5.0000e-04
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 36ms/step - accuracy: 0.8747 - loss: 0.3607 - val_accuracy: 0.8362 - val_loss: 0.5315 - learning_rate: 5.0000e-04
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8710 - loss: 0.3643 - val_accuracy: 0.8308 - val_loss: 0.5613 - learning_rate: 5.0000e-04
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8763 - loss: 0.3537 - val_accuracy: 0.8410 - val_loss: 0.5142 - learning_rate: 5.0000e-04
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8748 - loss: 0.3559 - val_accuracy: 0.8305 - val_loss: 0.5539 - learning_rate: 5.0000e-04
# Epoch 31/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.8786 - loss: 0.3483 - val_accuracy: 0.8359 - val_loss: 0.5218 - learning_rate: 5.0000e-04
# Epoch 32/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.8820 - loss: 0.3408 - val_accuracy: 0.8340 - val_loss: 0.5379 - learning_rate: 5.0000e-04
# Epoch 33/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8818 - loss: 0.3309 - val_accuracy: 0.8335 - val_loss: 0.5523 - learning_rate: 5.0000e-04
# Epoch 34/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.8802 - loss: 0.3341 - val_accuracy: 0.8463 - val_loss: 0.4977 - learning_rate: 5.0000e-04
# Epoch 35/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.8839 - loss: 0.3281 - val_accuracy: 0.8381 - val_loss: 0.5268 - learning_rate: 5.0000e-04
# Epoch 36/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.8864 - loss: 0.3238 - val_accuracy: 0.8385 - val_loss: 0.5347 - learning_rate: 5.0000e-04
# Epoch 37/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8887 - loss: 0.3151 - val_accuracy: 0.8389 - val_loss: 0.5340 - learning_rate: 5.0000e-04
# Epoch 38/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8894 - loss: 0.3189 - val_accuracy: 0.8349 - val_loss: 0.5506 - learning_rate: 5.0000e-04
# Epoch 39/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8876 - loss: 0.3134
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8876 - loss: 0.3134 - val_accuracy: 0.8340 - val_loss: 0.5534 - learning_rate: 5.0000e-04
# Epoch 40/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8991 - loss: 0.2838 - val_accuracy: 0.8457 - val_loss: 0.5253 - learning_rate: 2.5000e-04
# Epoch 41/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9047 - loss: 0.2699 - val_accuracy: 0.8448 - val_loss: 0.5396 - learning_rate: 2.5000e-04
# Epoch 42/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.9079 - loss: 0.2657 - val_accuracy: 0.8435 - val_loss: 0.5380 - learning_rate: 2.5000e-04
# Epoch 43/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9042 - loss: 0.2681 - val_accuracy: 0.8418 - val_loss: 0.5437 - learning_rate: 2.5000e-04
# Epoch 44/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9104 - loss: 0.2578 - val_accuracy: 0.8483 - val_loss: 0.5004 - learning_rate: 2.5000e-04
# Epoch 45/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9055 - loss: 0.2690 - val_accuracy: 0.8448 - val_loss: 0.5308 - learning_rate: 2.5000e-04
# Epoch 46/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 35ms/step - accuracy: 0.9083 - loss: 0.2583 - val_accuracy: 0.8451 - val_loss: 0.5309 - learning_rate: 2.5000e-04
# Epoch 47/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.9085 - loss: 0.2584 - val_accuracy: 0.8470 - val_loss: 0.5290 - learning_rate: 2.5000e-04
# Epoch 48/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9082 - loss: 0.2555 - val_accuracy: 0.8486 - val_loss: 0.5336 - learning_rate: 2.5000e-04
# Epoch 49/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9120 - loss: 0.2491 - val_accuracy: 0.8465 - val_loss: 0.5475 - learning_rate: 2.5000e-04
# Epoch 50/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9092 - loss: 0.2529 - val_accuracy: 0.8462 - val_loss: 0.5490 - learning_rate: 2.5000e-04
# Epoch 51/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9125 - loss: 0.2477 - val_accuracy: 0.8463 - val_loss: 0.5336 - learning_rate: 2.5000e-04
# Epoch 52/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.9163 - loss: 0.2362 - val_accuracy: 0.8495 - val_loss: 0.5259 - learning_rate: 2.5000e-04
# Epoch 53/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.9148 - loss: 0.2408 - val_accuracy: 0.8513 - val_loss: 0.5136 - learning_rate: 2.5000e-04
# Epoch 54/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9135 - loss: 0.2418 - val_accuracy: 0.8459 - val_loss: 0.5418 - learning_rate: 2.5000e-04
# Epoch 55/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.9150 - loss: 0.2366 - val_accuracy: 0.8516 - val_loss: 0.5042 - learning_rate: 2.5000e-04
# Epoch 56/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.9185 - loss: 0.2354 - val_accuracy: 0.8513 - val_loss: 0.5295 - learning_rate: 2.5000e-04
# Epoch 57/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9146 - loss: 0.2395 - val_accuracy: 0.8489 - val_loss: 0.5221 - learning_rate: 2.5000e-04
# Epoch 58/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 35ms/step - accuracy: 0.9154 - loss: 0.2402 - val_accuracy: 0.8471 - val_loss: 0.5502 - learning_rate: 2.5000e-04
# Epoch 59/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.9169 - loss: 0.2358 - val_accuracy: 0.8516 - val_loss: 0.5333 - learning_rate: 2.5000e-04
# Epoch 60/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9151 - loss: 0.2365
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.9151 - loss: 0.2365 - val_accuracy: 0.8437 - val_loss: 0.5597 - learning_rate: 2.5000e-04
# Epoch 61/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9247 - loss: 0.2140 - val_accuracy: 0.8524 - val_loss: 0.5457 - learning_rate: 1.2500e-04
# Epoch 62/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9267 - loss: 0.2082 - val_accuracy: 0.8517 - val_loss: 0.5304 - learning_rate: 1.2500e-04
# Epoch 63/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 37ms/step - accuracy: 0.9252 - loss: 0.2106 - val_accuracy: 0.8485 - val_loss: 0.5374 - learning_rate: 1.2500e-04
# Epoch 64/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.9276 - loss: 0.2075 - val_accuracy: 0.8486 - val_loss: 0.5440 - learning_rate: 1.2500e-04
# Epoch 65/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9299 - loss: 0.2032 - val_accuracy: 0.8529 - val_loss: 0.5363 - learning_rate: 1.2500e-04
# Epoch 66/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9270 - loss: 0.2018 - val_accuracy: 0.8491 - val_loss: 0.5502 - learning_rate: 1.2500e-04
# Epoch 67/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.9257 - loss: 0.2093 - val_accuracy: 0.8499 - val_loss: 0.5412 - learning_rate: 1.2500e-04
# Epoch 68/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.9268 - loss: 0.2045 - val_accuracy: 0.8473 - val_loss: 0.5458 - learning_rate: 1.2500e-04
# Epoch 69/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.9275 - loss: 0.1982 - val_accuracy: 0.8520 - val_loss: 0.5343 - learning_rate: 1.2500e-04
# Epoch 70/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9279 - loss: 0.2020
# Epoch 70: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.9279 - loss: 0.2020 - val_accuracy: 0.8518 - val_loss: 0.5296 - learning_rate: 1.2500e-04
# Epoch 71/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9306 - loss: 0.1952 - val_accuracy: 0.8488 - val_loss: 0.5533 - learning_rate: 6.2500e-05
# Epoch 72/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 36ms/step - accuracy: 0.9335 - loss: 0.1887 - val_accuracy: 0.8533 - val_loss: 0.5327 - learning_rate: 6.2500e-05
# Epoch 73/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.9332 - loss: 0.1869 - val_accuracy: 0.8545 - val_loss: 0.5313 - learning_rate: 6.2500e-05
# Epoch 74/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9345 - loss: 0.1901 - val_accuracy: 0.8508 - val_loss: 0.5486 - learning_rate: 6.2500e-05
# Epoch 75/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9349 - loss: 0.1836 - val_accuracy: 0.8499 - val_loss: 0.5530 - learning_rate: 6.2500e-05
# Epoch 76/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9290 - loss: 0.1948 - val_accuracy: 0.8528 - val_loss: 0.5449 - learning_rate: 6.2500e-05
# Epoch 77/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.9349 - loss: 0.1816 - val_accuracy: 0.8531 - val_loss: 0.5434 - learning_rate: 6.2500e-05
# Epoch 78/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9354 - loss: 0.1848
# Epoch 78: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 36ms/step - accuracy: 0.9354 - loss: 0.1848 - val_accuracy: 0.8527 - val_loss: 0.5483 - learning_rate: 6.2500e-05
# Epoch 79/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9353 - loss: 0.1844 - val_accuracy: 0.8538 - val_loss: 0.5411 - learning_rate: 3.1250e-05
# Epoch 80/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.9367 - loss: 0.1790 - val_accuracy: 0.8534 - val_loss: 0.5396 - learning_rate: 3.1250e-05
# Epoch 81/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.9387 - loss: 0.1746 - val_accuracy: 0.8533 - val_loss: 0.5405 - learning_rate: 3.1250e-05
# Epoch 82/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9343 - loss: 0.1829 - val_accuracy: 0.8525 - val_loss: 0.5487 - learning_rate: 3.1250e-05
# Epoch 83/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 37ms/step - accuracy: 0.9343 - loss: 0.1833 - val_accuracy: 0.8547 - val_loss: 0.5484 - learning_rate: 3.1250e-05
# Epoch 84/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.9370 - loss: 0.1743 - val_accuracy: 0.8535 - val_loss: 0.5473 - learning_rate: 3.1250e-05
# Epoch 85/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9350 - loss: 0.1807 - val_accuracy: 0.8518 - val_loss: 0.5503 - learning_rate: 3.1250e-05
# Epoch 86/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.9368 - loss: 0.1790 - val_accuracy: 0.8535 - val_loss: 0.5483 - learning_rate: 3.1250e-05
# Epoch 87/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9352 - loss: 0.1776 - val_accuracy: 0.8535 - val_loss: 0.5521 - learning_rate: 3.1250e-05
# Epoch 88/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9375 - loss: 0.1719
# Epoch 88: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9375 - loss: 0.1719 - val_accuracy: 0.8532 - val_loss: 0.5611 - learning_rate: 3.1250e-05
# Epoch 89/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.9361 - loss: 0.1803 - val_accuracy: 0.8553 - val_loss: 0.5558 - learning_rate: 1.5625e-05
# Epoch 90/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.9398 - loss: 0.1712 - val_accuracy: 0.8541 - val_loss: 0.5539 - learning_rate: 1.5625e-05
# Epoch 91/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9391 - loss: 0.1690 - val_accuracy: 0.8544 - val_loss: 0.5570 - learning_rate: 1.5625e-05
# Epoch 92/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.9378 - loss: 0.1738 - val_accuracy: 0.8532 - val_loss: 0.5539 - learning_rate: 1.5625e-05
# Epoch 93/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 36ms/step - accuracy: 0.9398 - loss: 0.1749 - val_accuracy: 0.8537 - val_loss: 0.5522 - learning_rate: 1.5625e-05
# Epoch 94/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9359 - loss: 0.1771
# Epoch 94: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9359 - loss: 0.1771 - val_accuracy: 0.8538 - val_loss: 0.5535 - learning_rate: 1.5625e-05
# Epoch 95/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.9389 - loss: 0.1706 - val_accuracy: 0.8544 - val_loss: 0.5486 - learning_rate: 7.8125e-06
# Epoch 96/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9396 - loss: 0.1675 - val_accuracy: 0.8540 - val_loss: 0.5483 - learning_rate: 7.8125e-06
# Epoch 97/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9396 - loss: 0.1719 - val_accuracy: 0.8536 - val_loss: 0.5480 - learning_rate: 7.8125e-06
# Epoch 98/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.9402 - loss: 0.1661 - val_accuracy: 0.8524 - val_loss: 0.5552 - learning_rate: 7.8125e-06
# Epoch 99/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9399 - loss: 0.1757
# Epoch 99: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.9399 - loss: 0.1757 - val_accuracy: 0.8536 - val_loss: 0.5512 - learning_rate: 7.8125e-06
# Epoch 100/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.9390 - loss: 0.1706 - val_accuracy: 0.8538 - val_loss: 0.5523 - learning_rate: 3.9063e-06
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8559 - loss: 0.5577
# Test Accuracy: 85.53%

# %%
# Predict the values from the validation dataset
y_pred = model.predict(x_test)
# Convert predictions classes to one hot vectors
y_pred_classes = np.argmax(y_pred,axis = 1)
# Convert validation observations to one hot vectors
y_true = np.argmax(y_test,axis = 1)
# compute the confusion matrix
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred_classes)


plt.figure(figsize=(12, 9))
c = sns.heatmap(confusion_mtx, annot=True, fmt='g')
c.set(xticklabels=cifar10_labels, yticklabels=cifar10_labels)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# [[Text(0.5, 0, '0'),
#   Text(1.5, 0, '1'),
#   Text(2.5, 0, '2'),
#   Text(3.5, 0, '3'),
#   Text(4.5, 0, '4'),
#   Text(5.5, 0, '5'),
#   Text(6.5, 0, '6'),
#   Text(7.5, 0, '7'),
#   Text(8.5, 0, '8'),
#   Text(9.5, 0, '9')],
#  [Text(0, 0.5, '0'),
#   Text(0, 1.5, '1'),
#   Text(0, 2.5, '2'),
#   Text(0, 3.5, '3'),
#   Text(0, 4.5, '4'),
#   Text(0, 5.5, '5'),
#   Text(0, 6.5, '6'),
#   Text(0, 7.5, '7'),
#   Text(0, 8.5, '8'),
#   Text(0, 9.5, '9')]]

# %%
import os
import json

# Create a folder to save everything
save_dir = "model_info"
os.makedirs(save_dir, exist_ok=True)

# 1. Save model architecture
with open(os.path.join(save_dir, "model_architecture.txt"), "w") as f:
    f.write(model.to_json())

# 2. Save model weights
model.save_weights(os.path.join(save_dir, "model_weights.weights.h5"))

# 3. Save training configuration
training_config = {
    "optimizer": "adam",
    "loss": "categorical_crossentropy",
    "metrics": ["accuracy"]
}
with open(os.path.join(save_dir, "training_config.json"), "w") as f:
    json.dump(training_config, f, indent=4)

# 4. Save training history
with open(os.path.join(save_dir, "training_history.json"), "w") as f:
    json.dump(history.history, f, indent=4)

# 5. Save class labels (CIFAR-10)
cifar10_labels = {
    0: "airplane",
    1: "automobile",
    2: "bird",
    3: "cat",
    4: "deer",
    5: "dog",
    6: "frog",
    7: "horse",
    8: "ship",
    9: "truck"
}
with open(os.path.join(save_dir, "class_labels.json"), "w") as f:
    json.dump(cifar10_labels, f, indent=4)

# 6. Save evaluation results
with open(os.path.join(save_dir, "evaluation_results.txt"), "w") as f:
    f.write(f"Test Loss: {test_loss}\n")
    f.write(f"Test Accuracy: {test_acc * 100:.2f}%\n")

print(f"All files saved in folder: {save_dir}")
# Out:
# All files saved in folder: model_info

# %%
import shutil

# Create a zip file from the folder
shutil.make_archive("model_info", 'zip', "model_info")
# Out:
# '/content/model_info.zip'

# %%
from google.colab import files
files.download("model_info.zip")

# %%
import os
import numpy as np
import json
import random
from tensorflow.keras.models import model_from_json
from tensorflow.keras.datasets import cifar10

# Load model architecture
with open("model_info/model_architecture.txt", "r") as f:
    model_json = f.read()

model = model_from_json(model_json)

# Load weights
model.load_weights("model_info/model_weights.weights.h5")

# Compile (you can match with training config)
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Load CIFAR-10 data
(_, _), (x_test, y_test) = cifar10.load_data()
x_test = x_test.astype("float32") / 255.0

# Load label mapping
with open("model_info/class_labels.json", "r") as f:
    label_map = json.load(f)

# Pick 10 random indices
indices = random.sample(range(len(x_test)), 10)

correct = 0
for idx in indices:
    img = np.expand_dims(x_test[idx], axis=0)  # shape (1, 32, 32, 3)
    pred_probs = model.predict(img, verbose=0)[0]
    pred_class = int(np.argmax(pred_probs))
    true_class = int(y_test[idx][0])

    pred_label = label_map[str(pred_class)]
    true_label = label_map[str(true_class)]

    is_correct = pred_class == true_class
    if is_correct:
        correct += 1

    print(f"Image {idx}: Predicted = {pred_class} ({pred_label}), Actual = {true_class} ({true_label})")

print(f"\n✅ Correct predictions: {correct}/10")
# Out:
# Image 4845: Predicted = 3 (cat), Actual = 3 (cat)
# Image 5157: Predicted = 6 (frog), Actual = 6 (frog)
# Image 8: Predicted = 3 (cat), Actual = 3 (cat)
# Image 353: Predicted = 2 (bird), Actual = 2 (bird)
# Image 2193: Predicted = 2 (bird), Actual = 2 (bird)
# Image 6963: Predicted = 9 (truck), Actual = 9 (truck)
# Image 9713: Predicted = 8 (ship), Actual = 8 (ship)
# Image 2837: Predicted = 8 (ship), Actual = 8 (ship)
# Image 1361: Predicted = 9 (truck), Actual = 9 (truck)
# Image 1092: Predicted = 6 (frog), Actual = 6 (frog)
#
# ✅ Correct predictions: 10/10

# %%
import os
import json
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import model_from_json
from tensorflow.keras.datasets import cifar10
import matplotlib.pyplot as plt

# === 1. Load saved model ===

# Set path to directory where files are saved
save_dir = "model_info"

# Load model architecture
with open(os.path.join(save_dir, "model_architecture.txt"), "r") as f:
    model_json = f.read()
model = model_from_json(model_json)

# Load model weights
model.load_weights(os.path.join(save_dir, "model_weights.weights.h5"))

# Compile model with default config for inference
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Load class labels
with open(os.path.join(save_dir, "class_labels.json"), "r") as f:
    class_labels = json.load(f)
class_labels = {int(k): v for k, v in class_labels.items()}

# === 2. Load CIFAR-10 and randomly select 5 images ===
(_, _), (x_test, y_test) = cifar10.load_data()

# Normalize input data
x_test = x_test.astype("float32") / 255.0

# If model expects one-hot labels during training, we only need raw labels for inference

# Random selection
idx = np.random.choice(len(x_test), size=5, replace=False)
sample_images = x_test[idx]
sample_labels = y_test[idx]

# === 3. Run inference ===
predictions = model.predict(sample_images)

# === 4. Show predictions ===
for i in range(5):
    plt.imshow(sample_images[i])
    plt.axis('off')
    pred_class = np.argmax(predictions[i])
    true_class = sample_labels[i][0]
    plt.title(f"Pred: {class_labels.get(pred_class, pred_class)}\nTrue: {class_labels.get(true_class, true_class)}")
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 790ms/step

# %%
import os
import shutil
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import model_from_json

# === CONFIG ===
model_arch_file = "model_info/model_architecture.txt"
weights_file = "model_info/model_weights.weights.h5"
weights_dir = "weights_txt"

# === Step 1: Clean the output folder ===
if os.path.exists(weights_dir):
    shutil.rmtree(weights_dir)
os.makedirs(weights_dir)

# === Step 2: Load model architecture ===
with open(model_arch_file, "r") as f:
    model_json = f.read()
model = model_from_json(model_json)

# === Step 3: Load weights ===
model.load_weights(weights_file)

# === Step 4: Export weights for each layer ===
for i, layer in enumerate(model.layers):
    weights = layer.get_weights()
    if not weights:
        continue  # Skip layers like Dropout, Pooling, Flatten

    for j, arr in enumerate(weights):
        # Determine the kind of weight
        if isinstance(layer, tf.keras.layers.BatchNormalization):
            kinds = ["gamma", "beta", "moving_mean", "moving_variance"]
            kind = kinds[j]
        else:
            kind = "kernel" if j == 0 else "bias"

        # Save flat weights
        weights_path = os.path.join(weights_dir, f"layer_{i}_{kind}.txt")
        np.savetxt(weights_path, arr.flatten(), fmt="%.18e")

        # Save shape
        shape_path = os.path.join(weights_dir, f"layer_{i}_{kind}_shape.txt")
        with open(shape_path, "w") as f:
            f.write(" ".join(map(str, arr.shape)))

print(f"✅ All layer weights exported to '{weights_dir}' as plain .txt files.")
# Out:
# ✅ All layer weights exported to 'weights_txt' as plain .txt files.

# %%
# !ls weights_txt/
# Out:
# layer_0_bias_shape.txt	   layer_1_kernel_shape.txt  layer_6_bias_shape.txt
# layer_0_bias.txt	   layer_1_kernel.txt	     layer_6_bias.txt
# layer_0_kernel_shape.txt   layer_3_bias_shape.txt    layer_6_kernel_shape.txt
# layer_0_kernel.txt	   layer_3_bias.txt	     layer_6_kernel.txt
# layer_10_bias_shape.txt    layer_3_kernel_shape.txt  layer_9_bias_shape.txt
# layer_10_bias.txt	   layer_3_kernel.txt	     layer_9_bias.txt
# layer_10_kernel_shape.txt  layer_4_bias_shape.txt    layer_9_kernel_shape.txt
# layer_10_kernel.txt	   layer_4_bias.txt	     layer_9_kernel.txt
# layer_1_bias_shape.txt	   layer_4_kernel_shape.txt
# layer_1_bias.txt	   layer_4_kernel.txt

# %%
import os
import zipfile

weights_dir = "weights_txt"
zip_filename = "weights_txt.zip"

with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, _, files in os.walk(weights_dir):
        for file in files:
            file_path = os.path.join(root, file)
            arcname = os.path.relpath(file_path, start=weights_dir)
            zipf.write(file_path, arcname)

print(f"✅ Zipped all files in '{weights_dir}' to '{zip_filename}'")
# Out:
# ✅ Zipped all files in 'weights_txt' to 'weights_txt.zip'
