# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1,
)
datagen.fit(x_train)

# Model architecture
from tensorflow.keras import models, layers

def build_model():
    model = models.Sequential()

    # Block 1
    model.add(layers.Conv2D(16, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)))
    model.add(layers.Conv2D(16, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=2))

    # Block 2
    model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=2))

    # Global Average Pooling replaces Flatten + Dense
    model.add(layers.GlobalAveragePooling2D())

    # Small final Dense
    model.add(layers.Dense(10, activation='softmax'))

    return model

model = build_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks
lr_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=5, factor=0.5, verbose=1)
early_stop = EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True)

# Train
history = model.fit(datagen.flow(x_train, y_train, batch_size=64),
                    validation_data=(x_test, y_test),
                    epochs=100,
                    callbacks=[lr_reduction, early_stop],
                    verbose=1)

# Evaluate
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc * 100:.2f}%")

# Plotting
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Test')
plt.title('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Test')
plt.title('Loss')
plt.legend()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 42ms/step - accuracy: 0.2249 - loss: 2.0607 - val_accuracy: 0.3684 - val_loss: 1.7136 - learning_rate: 0.0010
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.3774 - loss: 1.6833 - val_accuracy: 0.4173 - val_loss: 1.6537 - learning_rate: 0.0010
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.4241 - loss: 1.5736 - val_accuracy: 0.4637 - val_loss: 1.4793 - learning_rate: 0.0010
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.4552 - loss: 1.5038 - val_accuracy: 0.4614 - val_loss: 1.4845 - learning_rate: 0.0010
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.4727 - loss: 1.4564 - val_accuracy: 0.4913 - val_loss: 1.4159 - learning_rate: 0.0010
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.4958 - loss: 1.4064 - val_accuracy: 0.4939 - val_loss: 1.4018 - learning_rate: 0.0010
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.5097 - loss: 1.3697 - val_accuracy: 0.5404 - val_loss: 1.2905 - learning_rate: 0.0010
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.5167 - loss: 1.3420 - val_accuracy: 0.5357 - val_loss: 1.3068 - learning_rate: 0.0010
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.5332 - loss: 1.3038 - val_accuracy: 0.5330 - val_loss: 1.3092 - learning_rate: 0.0010
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.5431 - loss: 1.2799 - val_accuracy: 0.5451 - val_loss: 1.2948 - learning_rate: 0.0010
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.5615 - loss: 1.2300 - val_accuracy: 0.5554 - val_loss: 1.2585 - learning_rate: 0.0010
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.5667 - loss: 1.2108 - val_accuracy: 0.5712 - val_loss: 1.2257 - learning_rate: 0.0010
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.5762 - loss: 1.1860 - val_accuracy: 0.5848 - val_loss: 1.1860 - learning_rate: 0.0010
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.5835 - loss: 1.1759 - val_accuracy: 0.5836 - val_loss: 1.1892 - learning_rate: 0.0010
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.5929 - loss: 1.1524 - val_accuracy: 0.5865 - val_loss: 1.1861 - learning_rate: 0.0010
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.5964 - loss: 1.1354 - val_accuracy: 0.5794 - val_loss: 1.2357 - learning_rate: 0.0010
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.5994 - loss: 1.1209 - val_accuracy: 0.5651 - val_loss: 1.2861 - learning_rate: 0.0010
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6065 - loss: 1.1160 - val_accuracy: 0.6099 - val_loss: 1.1214 - learning_rate: 0.0010
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6168 - loss: 1.0868 - val_accuracy: 0.6263 - val_loss: 1.0646 - learning_rate: 0.0010
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 36ms/step - accuracy: 0.6174 - loss: 1.0820 - val_accuracy: 0.5869 - val_loss: 1.1842 - learning_rate: 0.0010
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6199 - loss: 1.0773 - val_accuracy: 0.5811 - val_loss: 1.2279 - learning_rate: 0.0010
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 36ms/step - accuracy: 0.6220 - loss: 1.0660 - val_accuracy: 0.6217 - val_loss: 1.0871 - learning_rate: 0.0010
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6274 - loss: 1.0476 - val_accuracy: 0.6020 - val_loss: 1.1581 - learning_rate: 0.0010
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6291 - loss: 1.0554
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6291 - loss: 1.0554 - val_accuracy: 0.6135 - val_loss: 1.1267 - learning_rate: 0.0010
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6393 - loss: 1.0154 - val_accuracy: 0.6427 - val_loss: 1.0470 - learning_rate: 5.0000e-04
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.6518 - loss: 0.9978 - val_accuracy: 0.6525 - val_loss: 1.0157 - learning_rate: 5.0000e-04
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6514 - loss: 0.9953 - val_accuracy: 0.6341 - val_loss: 1.0921 - learning_rate: 5.0000e-04
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6546 - loss: 0.9847 - val_accuracy: 0.6410 - val_loss: 1.0478 - learning_rate: 5.0000e-04
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6492 - loss: 0.9932 - val_accuracy: 0.6417 - val_loss: 1.0566 - learning_rate: 5.0000e-04
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6571 - loss: 0.9838 - val_accuracy: 0.6252 - val_loss: 1.1165 - learning_rate: 5.0000e-04
# Epoch 31/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6515 - loss: 0.9826
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6515 - loss: 0.9826 - val_accuracy: 0.6413 - val_loss: 1.0593 - learning_rate: 5.0000e-04
# Epoch 32/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6583 - loss: 0.9720 - val_accuracy: 0.6463 - val_loss: 1.0435 - learning_rate: 2.5000e-04
# Epoch 33/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6666 - loss: 0.9565 - val_accuracy: 0.6547 - val_loss: 1.0116 - learning_rate: 2.5000e-04
# Epoch 34/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.6652 - loss: 0.9538 - val_accuracy: 0.6367 - val_loss: 1.0761 - learning_rate: 2.5000e-04
# Epoch 35/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6673 - loss: 0.9509 - val_accuracy: 0.6488 - val_loss: 1.0467 - learning_rate: 2.5000e-04
# Epoch 36/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6669 - loss: 0.9486 - val_accuracy: 0.6639 - val_loss: 1.0029 - learning_rate: 2.5000e-04
# Epoch 37/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6665 - loss: 0.9480 - val_accuracy: 0.6521 - val_loss: 1.0197 - learning_rate: 2.5000e-04
# Epoch 38/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6656 - loss: 0.9522 - val_accuracy: 0.6693 - val_loss: 0.9780 - learning_rate: 2.5000e-04
# Epoch 39/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6710 - loss: 0.9425 - val_accuracy: 0.6582 - val_loss: 0.9976 - learning_rate: 2.5000e-04
# Epoch 40/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6698 - loss: 0.9419 - val_accuracy: 0.6607 - val_loss: 1.0008 - learning_rate: 2.5000e-04
# Epoch 41/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6710 - loss: 0.9405 - val_accuracy: 0.6565 - val_loss: 1.0111 - learning_rate: 2.5000e-04
# Epoch 42/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6682 - loss: 0.9411 - val_accuracy: 0.6469 - val_loss: 1.0486 - learning_rate: 2.5000e-04
# Epoch 43/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6720 - loss: 0.9347 - val_accuracy: 0.6739 - val_loss: 0.9503 - learning_rate: 2.5000e-04
# Epoch 44/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6728 - loss: 0.9314 - val_accuracy: 0.6623 - val_loss: 1.0194 - learning_rate: 2.5000e-04
# Epoch 45/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6703 - loss: 0.9360 - val_accuracy: 0.6615 - val_loss: 0.9994 - learning_rate: 2.5000e-04
# Epoch 46/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6751 - loss: 0.9328 - val_accuracy: 0.6548 - val_loss: 1.0225 - learning_rate: 2.5000e-04
# Epoch 47/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.6745 - loss: 0.9329 - val_accuracy: 0.6687 - val_loss: 0.9800 - learning_rate: 2.5000e-04
# Epoch 48/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6697 - loss: 0.9369
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6697 - loss: 0.9369 - val_accuracy: 0.6659 - val_loss: 0.9836 - learning_rate: 2.5000e-04
# Epoch 49/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6759 - loss: 0.9235 - val_accuracy: 0.6675 - val_loss: 0.9834 - learning_rate: 1.2500e-04
# Epoch 50/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6746 - loss: 0.9258 - val_accuracy: 0.6562 - val_loss: 1.0233 - learning_rate: 1.2500e-04
# Epoch 51/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6796 - loss: 0.9194 - val_accuracy: 0.6672 - val_loss: 0.9901 - learning_rate: 1.2500e-04
# Epoch 52/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6842 - loss: 0.9058 - val_accuracy: 0.6712 - val_loss: 0.9764 - learning_rate: 1.2500e-04
# Epoch 53/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6833 - loss: 0.9100
# Epoch 53: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6833 - loss: 0.9100 - val_accuracy: 0.6690 - val_loss: 0.9851 - learning_rate: 1.2500e-04
# Epoch 54/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6813 - loss: 0.9169 - val_accuracy: 0.6709 - val_loss: 0.9784 - learning_rate: 6.2500e-05
# Epoch 55/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6807 - loss: 0.9091 - val_accuracy: 0.6744 - val_loss: 0.9596 - learning_rate: 6.2500e-05
# Epoch 56/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6832 - loss: 0.9106 - val_accuracy: 0.6794 - val_loss: 0.9531 - learning_rate: 6.2500e-05
# Epoch 57/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6802 - loss: 0.9135 - val_accuracy: 0.6680 - val_loss: 0.9862 - learning_rate: 6.2500e-05
# Epoch 58/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6827 - loss: 0.9051 - val_accuracy: 0.6678 - val_loss: 0.9895 - learning_rate: 6.2500e-05
# Epoch 59/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6835 - loss: 0.9006 - val_accuracy: 0.6672 - val_loss: 0.9857 - learning_rate: 6.2500e-05
# Epoch 60/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6837 - loss: 0.9079 - val_accuracy: 0.6766 - val_loss: 0.9636 - learning_rate: 6.2500e-05
# Epoch 61/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6794 - loss: 0.9183
# Epoch 61: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 36ms/step - accuracy: 0.6794 - loss: 0.9183 - val_accuracy: 0.6697 - val_loss: 0.9873 - learning_rate: 6.2500e-05
# Epoch 62/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.6828 - loss: 0.9111 - val_accuracy: 0.6713 - val_loss: 0.9717 - learning_rate: 3.1250e-05
# Epoch 63/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6845 - loss: 0.9036 - val_accuracy: 0.6704 - val_loss: 0.9816 - learning_rate: 3.1250e-05
# Epoch 64/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6862 - loss: 0.9047 - val_accuracy: 0.6703 - val_loss: 0.9762 - learning_rate: 3.1250e-05
# Epoch 65/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6842 - loss: 0.9117 - val_accuracy: 0.6702 - val_loss: 0.9839 - learning_rate: 3.1250e-05
# Epoch 66/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6873 - loss: 0.9022
# Epoch 66: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6873 - loss: 0.9022 - val_accuracy: 0.6732 - val_loss: 0.9739 - learning_rate: 3.1250e-05
# Epoch 67/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6823 - loss: 0.9008 - val_accuracy: 0.6731 - val_loss: 0.9661 - learning_rate: 1.5625e-05
# Epoch 68/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6859 - loss: 0.8990 - val_accuracy: 0.6735 - val_loss: 0.9711 - learning_rate: 1.5625e-05
# Epoch 69/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6826 - loss: 0.9105 - val_accuracy: 0.6757 - val_loss: 0.9662 - learning_rate: 1.5625e-05
# Epoch 70/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.6804 - loss: 0.9128 - val_accuracy: 0.6716 - val_loss: 0.9766 - learning_rate: 1.5625e-05
# Epoch 71/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6833 - loss: 0.8984
# Epoch 71: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6833 - loss: 0.8984 - val_accuracy: 0.6750 - val_loss: 0.9655 - learning_rate: 1.5625e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6842 - loss: 0.9470
# Test Accuracy: 67.94%

# %%
model.save('model.keras')
