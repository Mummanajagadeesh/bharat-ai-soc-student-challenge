# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1,
)
datagen.fit(x_train)

# Model architecture
from tensorflow.keras import layers, models, Input

def build_model():
    inputs = Input(shape=(32, 32, 3))

    # === Block 1 (24 filters with residual connection) ===
    x = layers.Conv2D(28, (3, 3), padding='same', activation='relu')(inputs)
    x = layers.Conv2D(28, (3, 3), padding='same', activation='relu')(x)
    # Residual connection: input -> block output
    shortcut1 = layers.Conv2D(28, (1, 1), padding='same')(inputs)
    x = layers.Add()([x, shortcut1])
    x = layers.MaxPooling2D(pool_size=2)(x)

    # === Block 2 (48 filters with residual connection) ===
    block2_input = x  # store block input for proper residual
    x = layers.Conv2D(56, (3, 3), padding='same', activation='relu')(block2_input)
    x = layers.Conv2D(56, (3, 3), padding='same', activation='relu')(x)
    # Residual connection: block input -> block output
    shortcut2 = layers.Conv2D(56, (1, 1), padding='same')(block2_input)
    x = layers.Add()([x, shortcut2])
    x = layers.MaxPooling2D(pool_size=2)(x)

    # === Global Average Pooling ===
    x = layers.GlobalAveragePooling2D()(x)

    # === Output ===
    outputs = layers.Dense(10, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    return model

model = build_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks
lr_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=5, factor=0.5, verbose=1)
early_stop = EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True)

# Train
history = model.fit(datagen.flow(x_train, y_train, batch_size=64),
                    validation_data=(x_test, y_test),
                    epochs=100,
                    callbacks=[lr_reduction, early_stop],
                    verbose=1)

# Evaluate
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc * 100:.2f}%")

# Plotting
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Test')
plt.title('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Test')
plt.title('Loss')
plt.legend()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 14s 0us/step
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 46ms/step - accuracy: 0.2465 - loss: 1.9938 - val_accuracy: 0.3985 - val_loss: 1.6540 - learning_rate: 0.0010
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.4267 - loss: 1.5754 - val_accuracy: 0.4744 - val_loss: 1.4536 - learning_rate: 0.0010
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.4923 - loss: 1.4111 - val_accuracy: 0.5115 - val_loss: 1.3774 - learning_rate: 0.0010
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.5277 - loss: 1.3178 - val_accuracy: 0.5494 - val_loss: 1.2426 - learning_rate: 0.0010
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.5683 - loss: 1.2257 - val_accuracy: 0.5859 - val_loss: 1.1705 - learning_rate: 0.0010
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.5821 - loss: 1.1824 - val_accuracy: 0.5952 - val_loss: 1.1387 - learning_rate: 0.0010
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.6001 - loss: 1.1321 - val_accuracy: 0.6068 - val_loss: 1.1382 - learning_rate: 0.0010
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.6135 - loss: 1.1009 - val_accuracy: 0.6223 - val_loss: 1.0899 - learning_rate: 0.0010
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.6282 - loss: 1.0645 - val_accuracy: 0.6315 - val_loss: 1.0575 - learning_rate: 0.0010
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.6339 - loss: 1.0324 - val_accuracy: 0.6250 - val_loss: 1.0937 - learning_rate: 0.0010
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.6457 - loss: 1.0143 - val_accuracy: 0.6209 - val_loss: 1.1229 - learning_rate: 0.0010
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6514 - loss: 0.9910 - val_accuracy: 0.6465 - val_loss: 1.0487 - learning_rate: 0.0010
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6583 - loss: 0.9698 - val_accuracy: 0.6401 - val_loss: 1.0664 - learning_rate: 0.0010
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.6665 - loss: 0.9442 - val_accuracy: 0.6821 - val_loss: 0.9255 - learning_rate: 0.0010
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.6741 - loss: 0.9306 - val_accuracy: 0.6270 - val_loss: 1.1623 - learning_rate: 0.0010
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.6818 - loss: 0.9074 - val_accuracy: 0.6862 - val_loss: 0.9080 - learning_rate: 0.0010
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.6858 - loss: 0.8960 - val_accuracy: 0.6700 - val_loss: 0.9558 - learning_rate: 0.0010
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.6928 - loss: 0.8818 - val_accuracy: 0.6871 - val_loss: 0.9271 - learning_rate: 0.0010
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.6964 - loss: 0.8726 - val_accuracy: 0.6986 - val_loss: 0.8837 - learning_rate: 0.0010
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6979 - loss: 0.8561 - val_accuracy: 0.6917 - val_loss: 0.9254 - learning_rate: 0.0010
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.7076 - loss: 0.8360 - val_accuracy: 0.6988 - val_loss: 0.8997 - learning_rate: 0.0010
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7099 - loss: 0.8261 - val_accuracy: 0.6940 - val_loss: 0.9006 - learning_rate: 0.0010
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.7166 - loss: 0.8078 - val_accuracy: 0.7080 - val_loss: 0.8609 - learning_rate: 0.0010
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7212 - loss: 0.8014 - val_accuracy: 0.7080 - val_loss: 0.8721 - learning_rate: 0.0010
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.7279 - loss: 0.7857 - val_accuracy: 0.7162 - val_loss: 0.8487 - learning_rate: 0.0010
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7254 - loss: 0.7862 - val_accuracy: 0.7071 - val_loss: 0.8857 - learning_rate: 0.0010
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7304 - loss: 0.7706 - val_accuracy: 0.7151 - val_loss: 0.8623 - learning_rate: 0.0010
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7352 - loss: 0.7647 - val_accuracy: 0.7227 - val_loss: 0.8259 - learning_rate: 0.0010
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7361 - loss: 0.7488 - val_accuracy: 0.7175 - val_loss: 0.8387 - learning_rate: 0.0010
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7409 - loss: 0.7423 - val_accuracy: 0.7209 - val_loss: 0.8201 - learning_rate: 0.0010
# Epoch 31/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.7440 - loss: 0.7265 - val_accuracy: 0.7220 - val_loss: 0.8400 - learning_rate: 0.0010
# Epoch 32/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 41ms/step - accuracy: 0.7512 - loss: 0.7203 - val_accuracy: 0.7495 - val_loss: 0.7435 - learning_rate: 0.0010
# Epoch 33/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.7490 - loss: 0.7227 - val_accuracy: 0.7249 - val_loss: 0.8367 - learning_rate: 0.0010
# Epoch 34/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.7565 - loss: 0.7076 - val_accuracy: 0.7293 - val_loss: 0.8197 - learning_rate: 0.0010
# Epoch 35/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7563 - loss: 0.6997 - val_accuracy: 0.7372 - val_loss: 0.8065 - learning_rate: 0.0010
# Epoch 36/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.7616 - loss: 0.6866 - val_accuracy: 0.7425 - val_loss: 0.7764 - learning_rate: 0.0010
# Epoch 37/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7622 - loss: 0.6846 - val_accuracy: 0.7520 - val_loss: 0.7346 - learning_rate: 0.0010
# Epoch 38/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.7678 - loss: 0.6750 - val_accuracy: 0.7593 - val_loss: 0.7135 - learning_rate: 0.0010
# Epoch 39/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7622 - loss: 0.6824 - val_accuracy: 0.7513 - val_loss: 0.7543 - learning_rate: 0.0010
# Epoch 40/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.7701 - loss: 0.6606 - val_accuracy: 0.7493 - val_loss: 0.7588 - learning_rate: 0.0010
# Epoch 41/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7664 - loss: 0.6694 - val_accuracy: 0.7554 - val_loss: 0.7340 - learning_rate: 0.0010
# Epoch 42/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7703 - loss: 0.6605 - val_accuracy: 0.7629 - val_loss: 0.7132 - learning_rate: 0.0010
# Epoch 43/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.7723 - loss: 0.6574 - val_accuracy: 0.7627 - val_loss: 0.7125 - learning_rate: 0.0010
# Epoch 44/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7742 - loss: 0.6498 - val_accuracy: 0.7315 - val_loss: 0.8251 - learning_rate: 0.0010
# Epoch 45/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7752 - loss: 0.6497 - val_accuracy: 0.7495 - val_loss: 0.7817 - learning_rate: 0.0010
# Epoch 46/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 40ms/step - accuracy: 0.7810 - loss: 0.6309 - val_accuracy: 0.7567 - val_loss: 0.7679 - learning_rate: 0.0010
# Epoch 47/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.7791 - loss: 0.6354 - val_accuracy: 0.7671 - val_loss: 0.7187 - learning_rate: 0.0010
# Epoch 48/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7845 - loss: 0.6231 - val_accuracy: 0.7630 - val_loss: 0.7224 - learning_rate: 0.0010
# Epoch 49/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7825 - loss: 0.6289 - val_accuracy: 0.7599 - val_loss: 0.7498 - learning_rate: 0.0010
# Epoch 50/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7831 - loss: 0.6262 - val_accuracy: 0.7710 - val_loss: 0.7108 - learning_rate: 0.0010
# Epoch 51/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7854 - loss: 0.6166 - val_accuracy: 0.7794 - val_loss: 0.6653 - learning_rate: 0.0010
# Epoch 52/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7855 - loss: 0.6138 - val_accuracy: 0.7626 - val_loss: 0.7244 - learning_rate: 0.0010
# Epoch 53/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7882 - loss: 0.6107 - val_accuracy: 0.7726 - val_loss: 0.6943 - learning_rate: 0.0010
# Epoch 54/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7896 - loss: 0.6043 - val_accuracy: 0.7712 - val_loss: 0.6999 - learning_rate: 0.0010
# Epoch 55/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7921 - loss: 0.5996 - val_accuracy: 0.7637 - val_loss: 0.7065 - learning_rate: 0.0010
# Epoch 56/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7892 - loss: 0.6062
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7892 - loss: 0.6062 - val_accuracy: 0.7668 - val_loss: 0.7262 - learning_rate: 0.0010
# Epoch 57/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8040 - loss: 0.5678 - val_accuracy: 0.7844 - val_loss: 0.6641 - learning_rate: 5.0000e-04
# Epoch 58/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8036 - loss: 0.5596 - val_accuracy: 0.7795 - val_loss: 0.6925 - learning_rate: 5.0000e-04
# Epoch 59/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8029 - loss: 0.5639 - val_accuracy: 0.7684 - val_loss: 0.7271 - learning_rate: 5.0000e-04
# Epoch 60/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 40ms/step - accuracy: 0.8090 - loss: 0.5530 - val_accuracy: 0.7845 - val_loss: 0.6743 - learning_rate: 5.0000e-04
# Epoch 61/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8077 - loss: 0.5530 - val_accuracy: 0.7900 - val_loss: 0.6709 - learning_rate: 5.0000e-04
# Epoch 62/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.8054 - loss: 0.5596 - val_accuracy: 0.7891 - val_loss: 0.6599 - learning_rate: 5.0000e-04
# Epoch 63/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8091 - loss: 0.5490 - val_accuracy: 0.7796 - val_loss: 0.6873 - learning_rate: 5.0000e-04
# Epoch 64/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8110 - loss: 0.5446 - val_accuracy: 0.7833 - val_loss: 0.6876 - learning_rate: 5.0000e-04
# Epoch 65/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8102 - loss: 0.5471 - val_accuracy: 0.7830 - val_loss: 0.6785 - learning_rate: 5.0000e-04
# Epoch 66/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8104 - loss: 0.5483
# Epoch 66: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8104 - loss: 0.5483 - val_accuracy: 0.7735 - val_loss: 0.6925 - learning_rate: 5.0000e-04
# Epoch 67/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8185 - loss: 0.5250 - val_accuracy: 0.7897 - val_loss: 0.6706 - learning_rate: 2.5000e-04
# Epoch 68/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8174 - loss: 0.5277 - val_accuracy: 0.7990 - val_loss: 0.6155 - learning_rate: 2.5000e-04
# Epoch 69/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.8211 - loss: 0.5235 - val_accuracy: 0.7781 - val_loss: 0.7123 - learning_rate: 2.5000e-04
# Epoch 70/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 40ms/step - accuracy: 0.8188 - loss: 0.5269 - val_accuracy: 0.7991 - val_loss: 0.6287 - learning_rate: 2.5000e-04
# Epoch 71/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8236 - loss: 0.5125 - val_accuracy: 0.7887 - val_loss: 0.6778 - learning_rate: 2.5000e-04
# Epoch 72/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8157 - loss: 0.5285 - val_accuracy: 0.7992 - val_loss: 0.6289 - learning_rate: 2.5000e-04
# Epoch 73/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8179 - loss: 0.5215 - val_accuracy: 0.7923 - val_loss: 0.6493 - learning_rate: 2.5000e-04
# Epoch 74/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.8224 - loss: 0.5111 - val_accuracy: 0.7811 - val_loss: 0.6871 - learning_rate: 2.5000e-04
# Epoch 75/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8158 - loss: 0.5275 - val_accuracy: 0.8014 - val_loss: 0.6278 - learning_rate: 2.5000e-04
# Epoch 76/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8225 - loss: 0.5118 - val_accuracy: 0.7935 - val_loss: 0.6550 - learning_rate: 2.5000e-04
# Epoch 77/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8200 - loss: 0.5153 - val_accuracy: 0.7933 - val_loss: 0.6580 - learning_rate: 2.5000e-04
# Epoch 78/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8189 - loss: 0.5200 - val_accuracy: 0.8015 - val_loss: 0.6150 - learning_rate: 2.5000e-04
# Epoch 79/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8229 - loss: 0.5130 - val_accuracy: 0.7917 - val_loss: 0.6628 - learning_rate: 2.5000e-04
# Epoch 80/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8251 - loss: 0.5114 - val_accuracy: 0.7872 - val_loss: 0.6632 - learning_rate: 2.5000e-04
# Epoch 81/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.8211 - loss: 0.5135 - val_accuracy: 0.8018 - val_loss: 0.6274 - learning_rate: 2.5000e-04
# Epoch 82/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8227 - loss: 0.5071 - val_accuracy: 0.7970 - val_loss: 0.6375 - learning_rate: 2.5000e-04
# Epoch 83/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8196 - loss: 0.5133 - val_accuracy: 0.7969 - val_loss: 0.6384 - learning_rate: 2.5000e-04
# Epoch 84/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8239 - loss: 0.5041 - val_accuracy: 0.7952 - val_loss: 0.6328 - learning_rate: 2.5000e-04
# Epoch 85/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.8190 - loss: 0.5153 - val_accuracy: 0.8017 - val_loss: 0.6224 - learning_rate: 2.5000e-04
# Epoch 86/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8215 - loss: 0.5103
# Epoch 86: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8215 - loss: 0.5103 - val_accuracy: 0.7908 - val_loss: 0.6705 - learning_rate: 2.5000e-04
# Epoch 87/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8215 - loss: 0.5111 - val_accuracy: 0.7979 - val_loss: 0.6389 - learning_rate: 1.2500e-04
# Epoch 88/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8275 - loss: 0.4955 - val_accuracy: 0.8045 - val_loss: 0.6146 - learning_rate: 1.2500e-04
# Epoch 89/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8274 - loss: 0.5015 - val_accuracy: 0.7980 - val_loss: 0.6449 - learning_rate: 1.2500e-04
# Epoch 90/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.8276 - loss: 0.4981 - val_accuracy: 0.8034 - val_loss: 0.6183 - learning_rate: 1.2500e-04
# Epoch 91/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8257 - loss: 0.4963 - val_accuracy: 0.8036 - val_loss: 0.6222 - learning_rate: 1.2500e-04
# Epoch 92/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8315 - loss: 0.4897 - val_accuracy: 0.8025 - val_loss: 0.6312 - learning_rate: 1.2500e-04
# Epoch 93/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8277 - loss: 0.4922
# Epoch 93: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8277 - loss: 0.4922 - val_accuracy: 0.7985 - val_loss: 0.6348 - learning_rate: 1.2500e-04
# Epoch 94/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8305 - loss: 0.4889 - val_accuracy: 0.8042 - val_loss: 0.6194 - learning_rate: 6.2500e-05
# Epoch 95/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8265 - loss: 0.4965 - val_accuracy: 0.8018 - val_loss: 0.6269 - learning_rate: 6.2500e-05
# Epoch 96/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8266 - loss: 0.4988 - val_accuracy: 0.8038 - val_loss: 0.6290 - learning_rate: 6.2500e-05
# Epoch 97/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8283 - loss: 0.4936 - val_accuracy: 0.8039 - val_loss: 0.6232 - learning_rate: 6.2500e-05
# Epoch 98/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8288 - loss: 0.4958
# Epoch 98: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8288 - loss: 0.4958 - val_accuracy: 0.8019 - val_loss: 0.6326 - learning_rate: 6.2500e-05
# Epoch 99/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8318 - loss: 0.4826 - val_accuracy: 0.8027 - val_loss: 0.6260 - learning_rate: 3.1250e-05
# Epoch 100/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8294 - loss: 0.4929 - val_accuracy: 0.8017 - val_loss: 0.6330 - learning_rate: 3.1250e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8030 - loss: 0.6169
# Test Accuracy: 80.45%

# %%
model.save('model.keras')

# %%
from google.colab import files
files.download("model.keras")
