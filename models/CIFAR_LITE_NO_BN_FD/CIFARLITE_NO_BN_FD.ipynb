# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1,
)
datagen.fit(x_train)

# Model architecture
def build_model():
    model = models.Sequential()

    # Block 1
    model.add(layers.Conv2D(16, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)))
    model.add(layers.Conv2D(16, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=2))

    # Block 2
    model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=2))

    # Block 3
    model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=2))

    # Global Average Pooling replaces Flatten + Dense
    model.add(layers.GlobalAveragePooling2D())

    # Small final Dense
    model.add(layers.Dense(10, activation='softmax'))

    return model

model = build_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks
lr_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=5, factor=0.5, verbose=1)
early_stop = EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True)

# Train
history = model.fit(datagen.flow(x_train, y_train, batch_size=64),
                    validation_data=(x_test, y_test),
                    epochs=100,
                    callbacks=[lr_reduction, early_stop],
                    verbose=1)

# Evaluate
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc * 100:.2f}%")

# Plotting
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Test')
plt.title('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Test')
plt.title('Loss')
plt.legend()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 41ms/step - accuracy: 0.2640 - loss: 1.9315 - val_accuracy: 0.4525 - val_loss: 1.4718 - learning_rate: 0.0010
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.4630 - loss: 1.4681 - val_accuracy: 0.5456 - val_loss: 1.2686 - learning_rate: 0.0010
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.5294 - loss: 1.3052 - val_accuracy: 0.5688 - val_loss: 1.1795 - learning_rate: 0.0010
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.5731 - loss: 1.1839 - val_accuracy: 0.5940 - val_loss: 1.1706 - learning_rate: 0.0010
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.6003 - loss: 1.1131 - val_accuracy: 0.6226 - val_loss: 1.0854 - learning_rate: 0.0010
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.6306 - loss: 1.0449 - val_accuracy: 0.6279 - val_loss: 1.0648 - learning_rate: 0.0010
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.6501 - loss: 0.9928 - val_accuracy: 0.6620 - val_loss: 0.9600 - learning_rate: 0.0010
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.6744 - loss: 0.9304 - val_accuracy: 0.7017 - val_loss: 0.8456 - learning_rate: 0.0010
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.6779 - loss: 0.9034 - val_accuracy: 0.6920 - val_loss: 0.9285 - learning_rate: 0.0010
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.6988 - loss: 0.8650 - val_accuracy: 0.6881 - val_loss: 0.9154 - learning_rate: 0.0010
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.7128 - loss: 0.8294 - val_accuracy: 0.7255 - val_loss: 0.8005 - learning_rate: 0.0010
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.7193 - loss: 0.7993 - val_accuracy: 0.7197 - val_loss: 0.8306 - learning_rate: 0.0010
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.7273 - loss: 0.7747 - val_accuracy: 0.7227 - val_loss: 0.8196 - learning_rate: 0.0010
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 35ms/step - accuracy: 0.7400 - loss: 0.7508 - val_accuracy: 0.7402 - val_loss: 0.7563 - learning_rate: 0.0010
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.7408 - loss: 0.7396 - val_accuracy: 0.7416 - val_loss: 0.7878 - learning_rate: 0.0010
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 36ms/step - accuracy: 0.7464 - loss: 0.7226 - val_accuracy: 0.7491 - val_loss: 0.7353 - learning_rate: 0.0010
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.7515 - loss: 0.7113 - val_accuracy: 0.7259 - val_loss: 0.8311 - learning_rate: 0.0010
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.7578 - loss: 0.6986 - val_accuracy: 0.7382 - val_loss: 0.8039 - learning_rate: 0.0010
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.7616 - loss: 0.6837 - val_accuracy: 0.7532 - val_loss: 0.7417 - learning_rate: 0.0010
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.7656 - loss: 0.6748 - val_accuracy: 0.7723 - val_loss: 0.6794 - learning_rate: 0.0010
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.7716 - loss: 0.6591 - val_accuracy: 0.7753 - val_loss: 0.6597 - learning_rate: 0.0010
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.7808 - loss: 0.6365 - val_accuracy: 0.7653 - val_loss: 0.6944 - learning_rate: 0.0010
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.7784 - loss: 0.6343 - val_accuracy: 0.7697 - val_loss: 0.7055 - learning_rate: 0.0010
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.7837 - loss: 0.6225 - val_accuracy: 0.7738 - val_loss: 0.6999 - learning_rate: 0.0010
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.7867 - loss: 0.6194 - val_accuracy: 0.7707 - val_loss: 0.6907 - learning_rate: 0.0010
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.7889 - loss: 0.6039 - val_accuracy: 0.7876 - val_loss: 0.6513 - learning_rate: 0.0010
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 37ms/step - accuracy: 0.7910 - loss: 0.5973 - val_accuracy: 0.7880 - val_loss: 0.6415 - learning_rate: 0.0010
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.7973 - loss: 0.5864 - val_accuracy: 0.7869 - val_loss: 0.6510 - learning_rate: 0.0010
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.7984 - loss: 0.5755 - val_accuracy: 0.7811 - val_loss: 0.6745 - learning_rate: 0.0010
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.7993 - loss: 0.5808 - val_accuracy: 0.7964 - val_loss: 0.6225 - learning_rate: 0.0010
# Epoch 31/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.7986 - loss: 0.5804 - val_accuracy: 0.7839 - val_loss: 0.6789 - learning_rate: 0.0010
# Epoch 32/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8065 - loss: 0.5532 - val_accuracy: 0.7939 - val_loss: 0.6436 - learning_rate: 0.0010
# Epoch 33/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8012 - loss: 0.5686 - val_accuracy: 0.7845 - val_loss: 0.6689 - learning_rate: 0.0010
# Epoch 34/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.8067 - loss: 0.5554 - val_accuracy: 0.7701 - val_loss: 0.7273 - learning_rate: 0.0010
# Epoch 35/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8102 - loss: 0.5529
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.8102 - loss: 0.5529 - val_accuracy: 0.7893 - val_loss: 0.6486 - learning_rate: 0.0010
# Epoch 36/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.8221 - loss: 0.5146 - val_accuracy: 0.8064 - val_loss: 0.6054 - learning_rate: 5.0000e-04
# Epoch 37/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 36ms/step - accuracy: 0.8254 - loss: 0.4960 - val_accuracy: 0.8096 - val_loss: 0.5774 - learning_rate: 5.0000e-04
# Epoch 38/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8261 - loss: 0.4984 - val_accuracy: 0.8066 - val_loss: 0.5849 - learning_rate: 5.0000e-04
# Epoch 39/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.8296 - loss: 0.4900 - val_accuracy: 0.8092 - val_loss: 0.5844 - learning_rate: 5.0000e-04
# Epoch 40/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.8311 - loss: 0.4877 - val_accuracy: 0.8085 - val_loss: 0.5867 - learning_rate: 5.0000e-04
# Epoch 41/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 36ms/step - accuracy: 0.8271 - loss: 0.4957 - val_accuracy: 0.8163 - val_loss: 0.5542 - learning_rate: 5.0000e-04
# Epoch 42/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.8295 - loss: 0.4852 - val_accuracy: 0.7943 - val_loss: 0.6464 - learning_rate: 5.0000e-04
# Epoch 43/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.8301 - loss: 0.4894 - val_accuracy: 0.8133 - val_loss: 0.5705 - learning_rate: 5.0000e-04
# Epoch 44/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.8361 - loss: 0.4740 - val_accuracy: 0.8041 - val_loss: 0.6200 - learning_rate: 5.0000e-04
# Epoch 45/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8310 - loss: 0.4798 - val_accuracy: 0.8115 - val_loss: 0.5718 - learning_rate: 5.0000e-04
# Epoch 46/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8376 - loss: 0.4621
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8375 - loss: 0.4622 - val_accuracy: 0.8047 - val_loss: 0.6037 - learning_rate: 5.0000e-04
# Epoch 47/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8411 - loss: 0.4576 - val_accuracy: 0.8183 - val_loss: 0.5677 - learning_rate: 2.5000e-04
# Epoch 48/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.8412 - loss: 0.4556 - val_accuracy: 0.8188 - val_loss: 0.5779 - learning_rate: 2.5000e-04
# Epoch 49/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8441 - loss: 0.4467 - val_accuracy: 0.8055 - val_loss: 0.6315 - learning_rate: 2.5000e-04
# Epoch 50/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8471 - loss: 0.4441 - val_accuracy: 0.8159 - val_loss: 0.5766 - learning_rate: 2.5000e-04
# Epoch 51/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8460 - loss: 0.4484 - val_accuracy: 0.8141 - val_loss: 0.5848 - learning_rate: 2.5000e-04
# Epoch 52/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8457 - loss: 0.4433 - val_accuracy: 0.8220 - val_loss: 0.5603 - learning_rate: 2.5000e-04
# Epoch 53/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8464 - loss: 0.4355 - val_accuracy: 0.8199 - val_loss: 0.5632 - learning_rate: 2.5000e-04
# Epoch 54/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.8466 - loss: 0.4392 - val_accuracy: 0.8124 - val_loss: 0.5788 - learning_rate: 2.5000e-04
# Epoch 55/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.8459 - loss: 0.4393 - val_accuracy: 0.8118 - val_loss: 0.6129 - learning_rate: 2.5000e-04
# Epoch 56/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 36ms/step - accuracy: 0.8475 - loss: 0.4370 - val_accuracy: 0.8156 - val_loss: 0.5922 - learning_rate: 2.5000e-04
# Epoch 57/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8457 - loss: 0.4398
# Epoch 57: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.8457 - loss: 0.4398 - val_accuracy: 0.8210 - val_loss: 0.5644 - learning_rate: 2.5000e-04
# Epoch 58/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.8541 - loss: 0.4227 - val_accuracy: 0.8237 - val_loss: 0.5525 - learning_rate: 1.2500e-04
# Epoch 59/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8504 - loss: 0.4238 - val_accuracy: 0.8242 - val_loss: 0.5572 - learning_rate: 1.2500e-04
# Epoch 60/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8539 - loss: 0.4184 - val_accuracy: 0.8254 - val_loss: 0.5579 - learning_rate: 1.2500e-04
# Epoch 61/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.8540 - loss: 0.4201 - val_accuracy: 0.8213 - val_loss: 0.5634 - learning_rate: 1.2500e-04
# Epoch 62/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8544 - loss: 0.4176 - val_accuracy: 0.8285 - val_loss: 0.5516 - learning_rate: 1.2500e-04
# Epoch 63/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.8558 - loss: 0.4144 - val_accuracy: 0.8212 - val_loss: 0.5625 - learning_rate: 1.2500e-04
# Epoch 64/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.8548 - loss: 0.4175 - val_accuracy: 0.8141 - val_loss: 0.5975 - learning_rate: 1.2500e-04
# Epoch 65/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8562 - loss: 0.4166 - val_accuracy: 0.8257 - val_loss: 0.5544 - learning_rate: 1.2500e-04
# Epoch 66/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.8531 - loss: 0.4177 - val_accuracy: 0.8247 - val_loss: 0.5565 - learning_rate: 1.2500e-04
# Epoch 67/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8564 - loss: 0.4166
# Epoch 67: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.8564 - loss: 0.4166 - val_accuracy: 0.8280 - val_loss: 0.5427 - learning_rate: 1.2500e-04
# Epoch 68/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8539 - loss: 0.4181 - val_accuracy: 0.8224 - val_loss: 0.5685 - learning_rate: 6.2500e-05
# Epoch 69/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8568 - loss: 0.4078 - val_accuracy: 0.8263 - val_loss: 0.5425 - learning_rate: 6.2500e-05
# Epoch 70/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.8534 - loss: 0.4149 - val_accuracy: 0.8232 - val_loss: 0.5667 - learning_rate: 6.2500e-05
# Epoch 71/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.8553 - loss: 0.4126 - val_accuracy: 0.8305 - val_loss: 0.5417 - learning_rate: 6.2500e-05
# Epoch 72/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8571 - loss: 0.4116 - val_accuracy: 0.8274 - val_loss: 0.5511 - learning_rate: 6.2500e-05
# Epoch 73/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8569 - loss: 0.4104 - val_accuracy: 0.8266 - val_loss: 0.5494 - learning_rate: 6.2500e-05
# Epoch 74/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.8601 - loss: 0.3996 - val_accuracy: 0.8211 - val_loss: 0.5661 - learning_rate: 6.2500e-05
# Epoch 75/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8590 - loss: 0.4010 - val_accuracy: 0.8236 - val_loss: 0.5668 - learning_rate: 6.2500e-05
# Epoch 76/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8609 - loss: 0.4044
# Epoch 76: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.8609 - loss: 0.4044 - val_accuracy: 0.8259 - val_loss: 0.5563 - learning_rate: 6.2500e-05
# Epoch 77/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8599 - loss: 0.3979 - val_accuracy: 0.8223 - val_loss: 0.5615 - learning_rate: 3.1250e-05
# Epoch 78/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.8589 - loss: 0.4016 - val_accuracy: 0.8255 - val_loss: 0.5582 - learning_rate: 3.1250e-05
# Epoch 79/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8584 - loss: 0.4045 - val_accuracy: 0.8287 - val_loss: 0.5490 - learning_rate: 3.1250e-05
# Epoch 80/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8617 - loss: 0.4008 - val_accuracy: 0.8257 - val_loss: 0.5544 - learning_rate: 3.1250e-05
# Epoch 81/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8644 - loss: 0.3922
# Epoch 81: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.8644 - loss: 0.3922 - val_accuracy: 0.8255 - val_loss: 0.5560 - learning_rate: 3.1250e-05
# Epoch 82/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8615 - loss: 0.3959 - val_accuracy: 0.8271 - val_loss: 0.5474 - learning_rate: 1.5625e-05
# Epoch 83/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8586 - loss: 0.3977 - val_accuracy: 0.8239 - val_loss: 0.5646 - learning_rate: 1.5625e-05
# Epoch 84/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.8615 - loss: 0.3988 - val_accuracy: 0.8276 - val_loss: 0.5454 - learning_rate: 1.5625e-05
# Epoch 85/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8598 - loss: 0.3993 - val_accuracy: 0.8236 - val_loss: 0.5614 - learning_rate: 1.5625e-05
# Epoch 86/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8594 - loss: 0.4065
# Epoch 86: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 35ms/step - accuracy: 0.8594 - loss: 0.4065 - val_accuracy: 0.8267 - val_loss: 0.5516 - learning_rate: 1.5625e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8326 - loss: 0.5423
# Test Accuracy: 83.05%

# %%
model.save('model.keras')
